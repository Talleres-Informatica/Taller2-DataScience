# %% [markdown]
# # Taller 2: Introducción a Data Science

# %% [markdown]
# ### Integrantes:
# - Catalina Sanchez. Rut: 21190860-2
# - Samuel Fuentes. Rut:  20818020-7
# - Pamela Vera. Rut:  21564004-3

# %% [markdown]
# **Objetivo:** Aplicar técnicas de Aprendizaje No Supervisado para analizar el conjunto de datos de bebidas alcohólicas,
# descubriendo relaciones, agrupaciones y patrones relevantes en los datos. Opcionalmente, explorar el uso
# de Redes Neuronales para predecir ratings.
#
# *¿Existe algún patrón interesante que podamos detectar utilizando aprendizaje no supervisado con todos los datos?*

# %% [markdown]
# ## Librerías

# %%
# Installación de las librerías necesarias para el proyecto

# %%
# Importación de las librerías necesarias para el proyecto

# %% [markdown]
# ## Carga y Preprocesamiento de datos

# %% [markdown]
# ### Análisis exploratorio

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# ## 1. Reducción de Dimensionalidad

# %% [markdown]
# • Aplicar PCA y t-SNE para reducir la dimensionalidad de los datos. Visualizar los datos en 2D y 3D
# usando los componentes obtenidos. [15 puntos]
#
# • Analizar la varianza explicada por cada componente principal en PCA y encontrar la dimensión
# óptima según PCA utilizando los métodos vistos en clases. [5 puntos]
#
# • Discutir las diferencias entre PCA y t-SNE, y cómo se reflejan en las visualizaciones. [5 puntos]
#
# • Interprete las diferencias según las tres versiones de los conjuntos de datos. [5 puntos]

# %% [markdown]
# ## 2. Clustering

# %% [markdown]
# • Aplicar las técnicas de Clustering (k-Means) sobre los datos originales y los datos con
# dimensionalidad reducida. [15 puntos]
#
# • Utilizar el Método del Codo y Silhouette Score para determinar el número óptimo de clusters. Puede explorar otras métricas de evaluación de clusters. [15 puntos]
#
# • Comparar y discutir los resultados obtenidos por los distintos algoritmos. Visualizar los clusters
# obtenidos. [10 puntos]

# %% [markdown]
# ## 3. Interpretación de Resultados

# %% [markdown]
# • Analizar los clusters obtenidos. ¿Qué características distinguen a cada cluster? ¿Hay patrones
# generales interesantes? ¿Se correlacionan con alguna característica específica? ¿Es posible detectar subtipos interesantes de Tequila/Mezcal con los clusters? ¿Le podría asignar nombre a los clusters?
# [10 puntos]
#
# • ¿Podría ser útil la información obtenida de los clusters para entrenar un mejor modelo supervisado (clasificación o regresión)? [5 puntos]
#
# • Discutir posibles aplicaciones prácticas de estos resultados. [5 puntos]

# %% [markdown]
# ## 4. Conclusiones

# %% [markdown]
# • Presentar las principales conclusiones del análisis realizado. [5 puntos]
#
# • Discutir las ventajas y limitaciones de las técnicas de Aprendizaje No Supervisado aplicadas. [3
# puntos]
#
# • Proponer posibles extensiones o mejoras para un análisis futuro. [2 puntos]

# %% [markdown]
# ## 5. Extra: Redes Neuronales

# %% [markdown]
# • Implementar una Red Neuronal para predecir las variables estudiadas en el Taller 1. [10 puntos]
#
# • Probar distintas arquitecturas y funciones de activación. [5 puntos]
#
# • Comparar el desempeño de la Red Neuronal con los modelos anteriores (en función del R2
# y puntaje F1, según el tipo de modelo). [5 puntos]
